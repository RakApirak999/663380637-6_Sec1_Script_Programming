# %%
n = int(input("Enter a number for its multiplication table (e.g., 7): "))
for i in range(1, 13):
    print(f"{n} × {i} = {n*i}")

print()
# Out:
# 7 × 1 = 7
# 7 × 2 = 14
# 7 × 3 = 21
# 7 × 4 = 28
# 7 × 5 = 35
# 7 × 6 = 42
# 7 × 7 = 49
# 7 × 8 = 56
# 7 × 9 = 63
# 7 × 10 = 70
# 7 × 11 = 77
# 7 × 12 = 84
