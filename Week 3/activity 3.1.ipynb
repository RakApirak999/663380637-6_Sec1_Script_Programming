# %%
# Buggy Snippet A: Infinite Loop
# counter = 0
# while counter < 5:
#     print(counter)
#     # Missing counter increment!

# ไม่มีการเพิ่มค่า counter ทำให้ค่า counter น้อยกว่า 5 เสมอ จึงทำให้โปรแกรมจะทำงานไม่สิ้นสุด

counter = 0

while counter < 5:
    print(counter)
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Buggy Snippet B: Incorrect Range
# for i in range(1, 5): # Goal: print 1, 2, 3, 4, 5
#     print(i)

# range(1,5) จะได้แค่ 1-4

for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Buggy Snippet C: Misplaced Break
# for char in "hello":
#     if char == 'l':
#         print("Found 'l', stopping!")
#         break
#     print(char) # This will print 'h', 'e', 'l' then break

#  break เร็วเกินไป ทำให้ยังไม่ได้พิมพ์ตัว l แต่ระบบหยุดทำงานก่อนแล้ว

for char in "hello":
    print(char)

    if char == "l":
        print("Found l, stopping!")
        break
# Out:
# h
# e
# l
# Found l, stopping!
